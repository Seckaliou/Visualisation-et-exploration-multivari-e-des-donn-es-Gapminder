# %% [markdown]
# L'énoncé est volontairement lacunaire, pour une mise en situation réelle, il arrivera des fois où on ne vous donnera pas plus (voir même moins) d'informations.
# Trois méthodes pour résoudre ce problème:
# ChatGpt, fait en 3 secs
# Google, vous apprenez à chercher, c'est important
# Avec les trois liens donnés et votre IDE, vous apprenez à vous débrouiller avec ce que vous avez, niveau big boss
#
# Liens utiles:
# https://help.clicksend.com/en/articles/44235-what-is-a-unix-timestamp
# https://123timestamp.fr/
# https://pandas.pydata.org/docs/reference/frame.html

# %% [markdown]
# Expl en piece jointe sur fichier csv
#
# displayed_name,discord_id,has_joined,channel_name,timestamp
# David,xxxx,true,Test,1756204592
# Léa,xxxy,true,Test,1756204602
# François,xxyy,true,Test,1756204612
# Carole,xyyy,true,Impro,1756204622
# Carole,xyyy,false,Impro,1756205592

# %% [markdown]
# Petite mise à jour du Client (on met en pratique les cours de Roxane)
# Il faut lire le CSV que je vous ai fournis dans generate_graph, pas créer vos propres données
# En sortie de generate_graph vous devez avoir un Dataframe qui ressemble à ça
# Point bonus si vous créez une fonction qui exporte la Dataframe dans un excel avec le formattage conditionnel: invalide si la valeur est inférieure à 420
# https://xlsxwriter.readthedocs.io/example_pandas_conditional.html
#
# Le meilleur code sera mis en prod sur le Campus
# C'est votre occasion de contribuer à toutes les générations futures et à vous pavaner devant les Data Scientists

# %%
def generate_stats(start, end):
  """
  Retourne un dictionnaire, une série ou un dataframe qui associe à chaque utilisateur le temps (en seconde) qu'il a passé au total dans un canal vocal entre le timestamp 'start' et le timestamp 'end'
  Attention, un utilisateur peut être déjà dans un salon vocal au timestamp 'start' et peut ne pas l'avoir quitté au timestamp 'end'
  """
  ...

def generate_graph(dataframe_or_serie_or_dict):
  """
  Si vous êtes vraiment chaud vous pouvez générer un graph avec Pandas ou MathPlotLib, choisissez seulement un type des trois types d'entrée et générez le graph que vous pensez le plus pertinent pour ces données :)
  """
  ...

if __name__ == "__main__":
  # Vous pouvez tester avec 1756204590, 1756204601, 1756204602, 1756204603 comme début et 1756207599, 1756207609, 1756207615, 1756207612 comme fin
  ...
